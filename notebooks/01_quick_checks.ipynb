# %% [markdown]
# # Quick Checks for Order Intelligence CDC Pro
# Run this after the consumer has processed some events.

# %%
from pathlib import Path
import duckdb
import pandas as pd
DUCKDB_PATH = Path('..') / 'data' / 'order_intelligence.duckdb'
con = duckdb.connect(str(DUCKDB_PATH))
print('Connected to', DUCKDB_PATH.resolve())

# %%
con.execute("SHOW TABLES").df()

# %%
con.execute("SELECT entity, op, kafka_offset, processed_at FROM raw_cdc_events ORDER BY processed_at DESC LIMIT 20").df()

# %%
con.execute("SELECT * FROM orders_current ORDER BY order_ts DESC LIMIT 15").df()

# %%
con.execute("SELECT * FROM orders_summary").df()

# %%
con.execute("SELECT * FROM top_products LIMIT 10").df()
